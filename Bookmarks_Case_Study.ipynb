# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd
import sweetviz as sv
# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
bookmarks = pd.read_excel("C:/Users/user/Desktop/Industry_Projects/Bookmarks_Case_Study/All_Chrome_Bookmarks.xlsx")

# %%
import pandas as pd

df = pd.read_excel('C:/Users/user/Desktop/Industry_Projects/Bookmarks_Case_Study/All_Chrome_Bookmarks.xlsx') # can also index sheet by name or fetch all sheets
mylist = df['Column'].tolist()

# %%
mylist

mylist = list(map(lambda st: str.replace(st, "-", " "), mylist))

# %%
mylist
# Out:
# ['Intro to Artificial Intelligence   Udacity',
#  'Introduction to Machine Learning \xa0|\xa0 Machine Learning Crash Course \xa0|\xa0 Google Developers',
#  'Courses   Cognitive Class',
#  'Best Free Online Courses & eLearning: Start a Career & Learn to Earn',
#  'Data Science Certification Course – With Real Time Project And Job Support',
#  'Type conversion | Python',
#  'SAP Consultants Community in Egypt public group | Facebook',
#  'PI PO   Google Drive',
#  '03. Enterprise Services Repository.mp4   Google Drive',
#  'My openSAP | openSAP',
#  'SAP ABAP   Google Drive',
#  'Robotic Process Automation (RPA) Certification | UiPath Academy',
#  'Unit 5: Your Development Tools | ABAP Development for SAP HANA |',
#  'What is SAP PI/PO and how do you learn it with training',
#  'The Ultimate SAP User Guide: The Essential SAP Training Handbook for Consultants and Project Teams eBook: Rehan Zaidi, Jon Reed: Amazon.in: Kindle Store',
#  'SAP SD Training   in Plain English | Udemy',
# ...

# %%
#list1
#list1 = list1.upper()
lst = [x.upper() for x in list1]

# %%
df1 = pd.read_excel('C:/Users/user/Desktop/Industry_Projects/Bookmarks_Case_Study/new.xlsx')

# %%
df1[df1['keywords'] == 'PYTHON']
# Out:
#   keywords  counts
# 8   PYTHON      11

# %%
df1.head(20)
# Out:
#         keywords  counts
# 0            BUY      37
# 1            HOW      29
# 2           WHAT      15
# 3            THE      15
# 4           DATA      14
# 5          IELTS      14
# 6            SAP      13
# 7            TOP      11
# 8         PYTHON      11
# 9     AMAZON.IN:       8
# 10      DOWNLOAD       8
# 11         LEARN       8
# 12           MEN       7
# 13          JAVA       7
# 14  INTRODUCTION       7
# 15           NEW       7
# 16         AMCAT       6
# 17        GITHUB       6
# 18          SONY       5
# 19          FREE       5
